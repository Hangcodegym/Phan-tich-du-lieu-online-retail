# %% [markdown]
# # 1. Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('OnlineRetail.csv')
df
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 541904      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %% [markdown]
# # 2. Tạo cột mới có tên quý –  ‘Previous’ nhận giá trị 1 nếu ngày lập hóa đơn nằm trong các tháng 1,2,3; nhận giá trị 2 nếu ngày lập hóa đơn nằm trong các tháng 4,5,6; nhận giá trị 3 nếu ngày lập hóa đơn nằm trong các tháng 7,8,9;  nhận giá trị 4 nếu ngày lập hóa đơn nằm trong các tháng 10,11,12;

# %%
df.loc[:,'InvoiceDate'].str.split('/')
df.loc[:,'month']= temp.str[0] 
df
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 541904      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %%
conditions = [(df['month'] >='10'),
              (df['month'] >='7') & (df['month'] <'10'),
              (df['month'] >='4') & (df['month'] <'7'),
              (df['month'] <'4') & (df['month'] >='1')]
values = [4,3,2,1]
df['Previous']=np.select(conditions, values)
df
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 541904      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %%
df.to_csv('kiemtra6.csv')

# %% [markdown]
# # 3. Tạo một cột mới có tên ‘Amount’ có giá trị bằng Quantity * UnitPrice

# %%
df.loc[:,'Amount'] = df.loc[:,'Quantity']*df.loc[:,'UnitPrice']
df
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 541904      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %% [markdown]
# # 4.Tạo cột mới ‘Discount’ nhận giá trị 10% nếu Country là ‘United Kingdom’ và thuộc quý 4, 5% nếu là ‘France’ ngược lại là 0%.

# %%
conditions2 = [(df['Country'] =='United Kingdom') & (df['Previous']=='IV'),
              (df['Country'] =='France'),
              (df['Country'] !='France')]
     
values2 = [10, 5, 0]
df['Discount']=np.select(conditions2, values2)
df
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 541904      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
#  9   month        541909 non-null  object
#  10  date         541909 non-null  object
#  11  Previous     541909 non-null  int32
#  12  Amount       541909 non-null  float64
#  13  Discount     541909 non-null  int32
#  14  Total        541909 non-null  float64
# dtypes: float64(4), int32(2), int64(2), object(7)
# memory usage: 57.9+ MB

# %% [markdown]
# # 5. Tạo cột mới ‘Total’ nhận giá trị bằng: Amount – Discount.

# %%
df['Total']=df['Amount']-df['Amount']*(df['Discount']/100)
df
# Out:
#         Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0                0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                  WHITE METAL LANTERN
# 2                2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                  ...
# 541904      541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905      541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906      541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907      541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908      541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
# ...
